# %%
# !pip install -q streamlit==1.58.0
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 88.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 103.8 MB/s eta 0:00:00

# %% [markdown]
# Warning: This function may stop working due to changes in browser security.
# Try `serve_kernel_port_as_iframe` instead.

# %%
# 1. Запускаем Streamlit в фоновом режиме
# !streamlit run /content/streamlit_eda.py &>/dev/null &

# 2. Пауза для инициализации процесса
import time
time.sleep(3)

# 3. Запуск туннеля через альтернативный сервис Serveo
# !ssh -o StrictHostKeyChecking=no -R 80:127.0.0.1:8501 serveo.net
# Out:
# ...
# Forwarding HTTP traffic from https://dd749fb8ae22ed52-34-90-242-116.serveousercontent.com
# Tip (1): Create an account to reserve names. Pro removes the warning page: https://console.serveo.net/settings?n=1&src=ssh_nudge&v=A
